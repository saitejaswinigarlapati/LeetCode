# %%
dic={1:"one",2:"2",3:"3"}
dic
# Out:
# {1: 'one', 2: '2', 3: '3'}

# %%
if 1 in dic:
    print(dic[1])
# Out:
# one

# %%
dic[4]="four"
print(dic)
# Out:
# {1: 'one', 2: '2', 3: '3', 4: 'four'}

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None
        
node1=ListNode(1)
node2=ListNode(2)
node1.next=node2
print(node1.val)


temp=node1
print(temp)
# Out:
# 1
# ...
